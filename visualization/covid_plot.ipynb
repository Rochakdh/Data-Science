# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2019-12-31          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-01          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-02          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2019-12-31          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-01          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-02          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
print(df.columns)
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'tests_units', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
# ...

# %%
df['location']
# Out:
# 0          Afghanistan
# 1          Afghanistan
# 2          Afghanistan
# 3          Afghanistan
# 4          Afghanistan
#              ...
# 53311    International
# 53312    International
# 53313    International
# 53314    International
# 53315    International
# Name: location, Length: 53316, dtype: object

# %%
saarc_country = [ 'Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan','Sri Lanka']

# %%
print(saarc_country)
# Out:
# ['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka']

# %%
type(df['location'])
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2019-12-31          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-01          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-02          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
df.iloc[:4]
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2019-12-31          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-01          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-02          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# ...

# %%
df[['location','total_deaths']]
# Out:
#             location  total_deaths
# 0        Afghanistan           NaN
# 1        Afghanistan           NaN
# 2        Afghanistan           NaN
# 3        Afghanistan           NaN
# 4        Afghanistan           NaN
# ...              ...           ...
# 53311  International           7.0
# 53312  International           7.0
# 53313  International           7.0
# 53314  International           7.0
# 53315  International           7.0
#
# [53316 rows x 2 columns]

# %%
df.iloc[2,1]
# Out:
# 'Asia'

# %%
for index,row in df.iterrows():
    print(index,row['location'])
# Out:
# 0 Afghanistan
# 1 Afghanistan
# 2 Afghanistan
# 3 Afghanistan
# 4 Afghanistan
# 5 Afghanistan
# 6 Afghanistan
# 7 Afghanistan
# 8 Afghanistan
# 9 Afghanistan
# 10 Afghanistan
# 11 Afghanistan
# 12 Afghanistan
# 13 Afghanistan
# 14 Afghanistan
# 15 Afghanistan
# 16 Afghanistan
# 17 Afghanistan
# 18 Afghanistan
# 19 Afghanistan
# 20 Afghanistan
# 21 Afghanistan
# 22 Afghanistan
# 23 Afghanistan
# 24 Afghanistan
# 25 Afghanistan
# 26 Afghanistan
# 27 Afghanistan
# 28 Afghanistan
# 29 Afghanistan
# 30 Afghanistan
# 31 Afghanistan
# 32 Afghanistan
# 33 Afghanistan
# 34 Afghanistan
# 35 Afghanistan
# 36 Afghanistan
# 37 Afghanistan
# 38 Afghanistan
# 39 Afghanistan
# 40 Afghanistan
# 41 Afghanistan
# 42 Afghanistan
# 43 Afghanistan
# 44 Afghanistan
# 45 Afghanistan
# 46 Afghanistan
# 47 Afghanistan
# 48 Afghanistan
# 49 Afghanistan
# 50 Afghanistan
# 51 Afghanistan
# 52 Afghanistan
# 53 Afghanistan
# 54 Afghanistan
# 55 Afghanistan
# 56 Afghanistan
# 57 Afghanistan
# 58 Afghanistan
# ...

# %%
[df['location'].str.contains(i) for i in saarc_country]
# Out:
# [0         True
#  1         True
#  2         True
#  3         True
#  4         True
#           ...
#  53311    False
#  53312    False
#  53313    False
#  53314    False
#  53315    False
#  Name: location, Length: 53316, dtype: bool,
#  0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  53311    False
#  53312    False
#  53313    False
#  53314    False
#  53315    False
#  Name: location, Length: 53316, dtype: bool,
#  0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  53311    False
#  53312    False
#  53313    False
#  53314    False
#  53315    False
#  Name: location, Length: 53316, dtype: bool,
#  0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  53311    False
#  53312    False
#  53313    False
#  53314    False
#  53315    False
#  Name: location, Length: 53316, dtype: bool,
#  0        False
# ...

# %%
for row in df.drop_duplicates(subset=['location'],keep='last'):
    print(row)
#     if row['location'] in saarc_country:
#         print(index,row['location','total_deaths'])
# Out:
# iso_code
# continent
# location
# date
# total_cases
# new_cases
# new_cases_smoothed
# total_deaths
# new_deaths
# new_deaths_smoothed
# total_cases_per_million
# new_cases_per_million
# new_cases_smoothed_per_million
# total_deaths_per_million
# new_deaths_per_million
# new_deaths_smoothed_per_million
# icu_patients
# icu_patients_per_million
# hosp_patients
# hosp_patients_per_million
# weekly_icu_admissions
# weekly_icu_admissions_per_million
# weekly_hosp_admissions
# weekly_hosp_admissions_per_million
# total_tests
# new_tests
# total_tests_per_thousand
# new_tests_per_thousand
# new_tests_smoothed
# new_tests_smoothed_per_thousand
# tests_per_case
# positive_rate
# tests_units
# stringency_index
# population
# population_density
# median_age
# aged_65_older
# aged_70_older
# gdp_per_capita
# extreme_poverty
# cardiovasc_death_rate
# diabetes_prevalence
# female_smokers
# male_smokers
# handwashing_facilities
# hospital_beds_per_thousand
# life_expectancy
# ...

# %%
df.drop_duplicates(subset=['location'],keep='last')
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 303         AFG      Asia    Afghanistan  2020-10-29      41145.0        0.0
# 538         ALB    Europe        Albania  2020-10-29      20040.0      311.0
# 842         DZA    Africa        Algeria  2020-10-29      57026.0      320.0
# 1078        AND    Europe        Andorra  2020-10-29       4517.0      107.0
# 1300        AGO    Africa         Angola  2020-10-29       9871.0      227.0
# ...         ...       ...            ...         ...          ...        ...
# 52259       YEM      Asia          Yemen  2020-10-29       2064.0        0.0
# 52484       ZMB    Africa         Zambia  2020-10-29      16325.0       82.0
# 52707       ZWE    Africa       Zimbabwe  2020-10-29       8320.0        5.0
# 53011  OWID_WRL       NaN          World  2020-10-29   44574981.0   479707.0
# 53315       NaN       NaN  International  2020-10-29        696.0        NaN
#
# ...

# %%
for index,row in df.drop_duplicates(subset=['location'],keep='last').iterrows():
    if row['location'] in saarc_country:
        print(row[['location','total_deaths']])
# Out:
# location        Afghanistan
# total_deaths           1529
# Name: 303, dtype: object
# location        Bangladesh
# total_deaths          5861
# Name: 4193, dtype: object
# location        Bhutan
# total_deaths       NaN
# Name: 5929, dtype: object
# location         India
# total_deaths    120527
# Name: 22605, dtype: object
# location        Maldives
# total_deaths          37
# Name: 30404, dtype: object
# location        Nepal
# total_deaths      887
# Name: 34106, dtype: object
# location        Pakistan
# total_deaths        6775
# Name: 36814, dtype: object
# location        Sri Lanka
# total_deaths           19
# Name: 45139, dtype: object

# %%
quantity=[]
label=[]
saarc_country = [ 'Afghanistan', 'Bangladesh', 'Maldives', 'Pakistan','India','Sri Lanka','Nepal']
for index,row in df.drop_duplicates(subset=['location'],keep='last').iterrows():
    if row['location'] in saarc_country:
        quantity.append(row[['total_deaths']][0])
        label.append(row[['iso_code']][0])
print(label)
print(quantity)
plt.pie(quantity,labels=label ,autopct='%1.1f%%',radius = 3,shadow=True,textprops={'fontsize': 10},colors=['purple','yellow','orange','teal','green','brown'])
plt.show()
plt.bar(label,quantity,width=0.3)
plt.show()
# Out:
# ['AFG', 'BGD', 'IND', 'MDV', 'NPL', 'PAK', 'LKA']
# [1529.0, 5861.0, 120527.0, 37.0, 887.0, 6775.0, 19.0]

# %%
newcases=[]
for index,row in df.iterrows():
    if row['location']=='India':
        newcases.append(row['new_cases'])
# print(newcases)
plt.plot(newcases,color='red',linestyle='solid',linewidth=0.8)
plt.show()
